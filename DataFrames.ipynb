# %%
import numpy as np

# %%
import pandas as pd

# %%
np.random.seed(101)
myData = np.random.randint(0,101,(4,3))

# %%
myData
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myIndex = ['teh','maz','shr','isf']

# %%
myColumns = ['far','ord','khr']

# %%
df = pd.DataFrame(myData)

# %%
df
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
df = pd.DataFrame(data=myData, index=myIndex, columns=myColumns)
# OR
#df = pd.DataFrame(myData, myIndex, myColumns)

# %%
df
# Out:
#      far  ord  khr
# teh   95   11   81
# maz   70   63   87
# shr   75    9   77
# isf   40    4   63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, teh to isf
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   far     4 non-null      int32
#  1   ord     4 non-null      int32
#  2   khr     4 non-null      int32
# dtypes: int32(3)
# memory usage: 80.0+ bytes

# %%
pwd
# Out:
# 'C:\\Users\\Chalus System\\Machine learning libraries\\Pandas'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 08A7-BE6D
#
#  Directory of C:\Users\Chalus System\Machine learning libraries\Pandas
#
# 07/11/2024  02:16 PM    <DIR>          .
# 07/11/2024  02:16 PM    <DIR>          ..
# 07/10/2024  05:42 PM    <DIR>          .ipynb_checkpoints
# 07/11/2024  02:16 PM           160,409 DataFrames.ipynb
# 07/10/2024  05:41 PM            12,515 Series.ipynb
# 07/10/2024  06:14 PM            18,752 tips.csv
#                3 File(s)        191,676 bytes
#                3 Dir(s)  26,628,718,592 bytes free

# %%
#df = pd.read_csv("tips.csv")
# OR
df = pd.read_csv('C:\\Users\\Chalus System\\Machine learning libraries\\Pandas\\tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head()
# show the beganing of the dataset
# by deafult it shows 5 rows
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# ...

# %%
df.tail()
# show the end of the dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.describe() 

# give us a description of numeric column. in this case we have 5 numeric columns
# sometimes the column description is nonesense and useless for example average of credit card(cc) number,
# so we can drop that column
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose()

#change the columns and rows
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %% [markdown]
# ## columns

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df['total_bill'].head()
# Out:
# 0    16.99
# 1    10.34
# 2    21.01
# 3    23.68
# 4    24.59
# Name: total_bill, dtype: float64

# %%
colms=['total_bill','tip']
df[colms]
# OR
#df[['total_bill','tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df['tip'] * df["total_bill"] / 100
# Out:
# 0      0.171599
# 1      0.171644
# 2      0.735350
# 3      0.783808
# 4      0.887699
#          ...
# 239    1.718576
# 240    0.543600
# 241    0.453400
# 242    0.311850
# 243    0.563400
# Length: 244, dtype: float64

# %%
# Adding new column

df['tip_3'] = df['tip'] * df["total_bill"] / 100

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID     tip_3
# 0  Christy Cunningham  3560325168603410    Sun2959  0.171599
# 1      Douglas Tucker  4478071379779230    Sun4608  0.171644
# 2      Travis Walters  6011812112971322    Sun4458  0.735350
# 3    Nathaniel Harris  4676137647685994    Sun5260  0.783808
# 4        Tonya Carter  4832732618637221    Sun2251  0.887699

# %%
df["price_per_person"] = df["tip"] * df["total_bill"]

# overwrite the column price_per_person with new value

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2           17.1599
# 1       10.34  1.66    Male     No  Sun  Dinner     3           17.1644
# 2       21.01  3.50    Male     No  Sun  Dinner     3           73.5350
# 3       23.68  3.31    Male     No  Sun  Dinner     2           78.3808
# 4       24.59  3.61  Female     No  Sun  Dinner     4           88.7699
#
#            Payer Name         CC Number Payment ID     tip_3
# 0  Christy Cunningham  3560325168603410    Sun2959  0.171599
# 1      Douglas Tucker  4478071379779230    Sun4608  0.171644
# 2      Travis Walters  6011812112971322    Sun4458  0.735350
# 3    Nathaniel Harris  4676137647685994    Sun5260  0.783808
# 4        Tonya Carter  4832732618637221    Sun2251  0.887699

# %%
df["price_per_person"] = np.round(df["tip"] * df["total_bill"],2)

# round the price_per_person numbers with 2 decimals

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2             17.16
# 1       10.34  1.66    Male     No  Sun  Dinner     3             17.16
# 2       21.01  3.50    Male     No  Sun  Dinner     3             73.54
# 3       23.68  3.31    Male     No  Sun  Dinner     2             78.38
# 4       24.59  3.61  Female     No  Sun  Dinner     4             88.77
#
#            Payer Name         CC Number Payment ID     tip_3
# 0  Christy Cunningham  3560325168603410    Sun2959  0.171599
# 1      Douglas Tucker  4478071379779230    Sun4608  0.171644
# 2      Travis Walters  6011812112971322    Sun4458  0.735350
# 3    Nathaniel Harris  4676137647685994    Sun5260  0.783808
# 4        Tonya Carter  4832732618637221    Sun2251  0.887699

# %%
# Deleting columns

df.drop("tip_3",axis=1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2             17.16
# 1         10.34  1.66    Male     No   Sun  Dinner     3             17.16
# 2         21.01  3.50    Male     No   Sun  Dinner     3             73.54
# 3         23.68  3.31    Male     No   Sun  Dinner     2             78.38
# 4         24.59  3.61  Female     No   Sun  Dinner     4             88.77
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3            171.86
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             54.36
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             45.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2             31.18
# 243       18.78  3.00  Female     No  Thur  Dinner     2             56.34
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2             17.16
# 1       10.34  1.66    Male     No  Sun  Dinner     3             17.16
# 2       21.01  3.50    Male     No  Sun  Dinner     3             73.54
# 3       23.68  3.31    Male     No  Sun  Dinner     2             78.38
# 4       24.59  3.61  Female     No  Sun  Dinner     4             88.77
#
#            Payer Name         CC Number Payment ID     tip_3
# 0  Christy Cunningham  3560325168603410    Sun2959  0.171599
# 1      Douglas Tucker  4478071379779230    Sun4608  0.171644
# 2      Travis Walters  6011812112971322    Sun4458  0.735350
# 3    Nathaniel Harris  4676137647685994    Sun5260  0.783808
# 4        Tonya Carter  4832732618637221    Sun2251  0.887699

# %%
# to delet for always:

df = df.drop("tip_3",axis=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2             17.16
# 1       10.34  1.66    Male     No  Sun  Dinner     3             17.16
# 2       21.01  3.50    Male     No  Sun  Dinner     3             73.54
# 3       23.68  3.31    Male     No  Sun  Dinner     2             78.38
# 4       24.59  3.61  Female     No  Sun  Dinner     4             88.77
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.shape
# Out:
# (244, 11)

# %%
df.shape[0]
# 0 for rows
# Out:
# 244

# %%
df.shape[1]
# 1 for columns
# Out:
# 11

# %%
df.set_index("Payment ID")
# now payment ID is not a column, its now an index
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                17.16  Christy Cunningham  3560325168603410
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2             17.16
# 1       10.34  1.66    Male     No  Sun  Dinner     3             17.16
# 2       21.01  3.50    Male     No  Sun  Dinner     3             73.54
# 3       23.68  3.31    Male     No  Sun  Dinner     2             78.38
# 4       24.59  3.61  Female     No  Sun  Dinner     4             88.77
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
# in order to make it constant:

df = df.set_index("Payment ID")

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                17.16  Christy Cunningham  3560325168603410
# Sun4608                17.16      Douglas Tucker  4478071379779230
# Sun4458                73.54      Travis Walters  6011812112971322
# Sun5260                78.38    Nathaniel Harris  4676137647685994
# Sun2251                88.77        Tonya Carter  4832732618637221

# %%
df = df.reset_index()
# to reset the index

# %%
df.head()
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number
# 0             17.16  Christy Cunningham  3560325168603410
# 1             17.16      Douglas Tucker  4478071379779230
# 2             73.54      Travis Walters  6011812112971322
# 3             78.38    Nathaniel Harris  4676137647685994
# 4             88.77        Tonya Carter  4832732618637221

# %%
df = df.set_index("Payment ID")

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                17.16  Christy Cunningham  3560325168603410
# Sun4608                17.16      Douglas Tucker  4478071379779230
# Sun4458                73.54      Travis Walters  6011812112971322
# Sun5260                78.38    Nathaniel Harris  4676137647685994
# Sun2251                88.77        Tonya Carter  4832732618637221

# %% [markdown]
# ## Rows

# %%
df.iloc[0]
# integer location by only using index
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                 17.16
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df.loc["Sun2959"]
# location by using only lable index
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                 17.16
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df.iloc[0:5]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                17.16  Christy Cunningham  3560325168603410
# Sun4608                17.16      Douglas Tucker  4478071379779230
# Sun4458                73.54      Travis Walters  6011812112971322
# Sun5260                78.38    Nathaniel Harris  4676137647685994
# Sun2251                88.77        Tonya Carter  4832732618637221

# %%
df.loc[["Sun2959","Sun4608","Sun2251"]]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                17.16  Christy Cunningham  3560325168603410
# Sun4608                17.16      Douglas Tucker  4478071379779230
# Sun2251                88.77        Tonya Carter  4832732618637221

# %%
df.drop("Sun2959",axis=0)
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                17.16    Douglas Tucker  4478071379779230
# ...

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                17.16  Christy Cunningham  3560325168603410
# Sun4608                17.16      Douglas Tucker  4478071379779230
# Sun4458                73.54      Travis Walters  6011812112971322
# Sun5260                78.38    Nathaniel Harris  4676137647685994
# Sun2251                88.77        Tonya Carter  4832732618637221

# %%
# in order to delete the row for ever:

df = df.drop("Sun2959",axis=0)

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                17.16    Douglas Tucker  4478071379779230
# Sun4458                73.54    Travis Walters  6011812112971322
# Sun5260                78.38  Nathaniel Harris  4676137647685994
# Sun2251                88.77      Tonya Carter  4832732618637221
# Sun9679               119.12        Erik Smith   213140353657882

# %%
one_row = df.iloc[0]

# %%
one_row
# Out:
# total_bill                     10.34
# tip                             1.66
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               3
# price_per_person               17.16
# Payer Name            Douglas Tucker
# CC Number           4478071379779230
# Name: Sun4608, dtype: object

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                17.16    Douglas Tucker  4478071379779230
# ...

# %%
df = df._append(one_row)

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                17.16    Douglas Tucker  4478071379779230
# ...
